# %%
from sentinel_tiles import sentinel_tiles
from VNP21A1D_002 import VNP21A1D

# %%
tile = "11SPS"
date_UTC = "2025-05-27"

# %%
geometry = sentinel_tiles.grid(tile)
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
VNP21A1D_connection = VNP21A1D()
VNP21A1D_connection

# %%
VNP21A1D_connection.variable(variable="ST_K", date_UTC=date_UTC, geometry=geometry)
# Out:
# [2025-05-29 12:40:04 INFO] You're now authenticated with NASA Earthdata Login
# [2025-05-29 12:40:06 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2025-05-29 12:40:06 INFO]   VNP21A1D.A2025147.h08v05.002.2025148135613
# [2025-05-29 12:40:06 INFO] Number of VIIRS 2 granules found using CMR search: 1
# [2025-05-29 12:40:06 INFO]  Getting 1 granules, approx download size: 0.0 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-05-29 12:40:06 INFO] File VNP21A1D.A2025147.h08v05.002.2025148135613.h5 already downloaded
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-05-29 12:40:06 INFO] opening VIIRS file: ~/Projects/VNP21A1D-002/VNP21A1D.002/2025-05-27/VNP21A1D.A2025147.h08v05.002.2025148135613.h5
# [2025-05-29 12:40:06 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_Daily_1km_LST21/Data Fields/LST_1KM at 926.63 m resolution
# ...

# %%
VNP21A1D_connection.variable(variable="Emis_14", date_UTC=date_UTC, geometry=geometry)
# Out:
# [2025-05-29 12:41:00 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2025-05-29 12:41:00 INFO]   VNP21A1D.A2025147.h08v05.002.2025148135613
# [2025-05-29 12:41:00 INFO] Number of VIIRS 2 granules found using CMR search: 1
# [2025-05-29 12:41:00 INFO]  Getting 1 granules, approx download size: 0.0 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-05-29 12:41:00 INFO] File VNP21A1D.A2025147.h08v05.002.2025148135613.h5 already downloaded
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-05-29 12:41:00 INFO] opening VIIRS file: ~/Projects/VNP21A1D-002/VNP21A1D.002/2025-05-27/VNP21A1D.A2025147.h08v05.002.2025148135613.h5
# [2025-05-29 12:41:00 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_Daily_1km_LST21/Data Fields/Emis_14 at 926.63 m resolution
# ...
