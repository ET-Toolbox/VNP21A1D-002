# %%
import VNP21A1D_002

# %%
import logging

logger = logging.getLogger(__name__)

# %%
tile = "h08v05"
date_UTC = "2025-01-17"

# %%
granule = VNP21A1D_002.retrieve_granule(
    date_UTC=date_UTC,
    tile=tile
)

granule
# Out:
# [2025-09-28 14:44:06 INFO] You're now authenticated with NASA Earthdata Login
# [2025-09-28 14:44:08 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2025-09-28 14:44:08 INFO]   VNP21A1D.A2025017.h08v05.002.2025022014218
# [2025-09-28 14:44:08 INFO] Number of VIIRS 2 granules found using CMR search: 1
# [2025-09-28 14:44:08 INFO]  Getting 1 granules, approx download size: 0.0 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "filename": "~/data/VNP21A1D_002/VNP21A1D.002/2025-01-17/VNP21A1D.A2025017.h08v05.002.2025022014218.h5"
# }

# %%
granule.ST_C
# Out:
# [2025-09-28 14:44:11 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP21A1D.002/2025-01-17/VNP21A1D.A2025017.h08v05.002.2025022014218.h5
# [2025-09-28 14:44:11 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_Daily_1km_LST21/Data Fields/LST_1KM at 926.63 m resolution
# [2025-09-28 14:44:11 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP21A1D.002/2025-01-17/VNP21A1D.A2025017.h08v05.002.2025022014218.h5
# [2025-09-28 14:44:11 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_Daily_1km_LST21/Data Fields/QC at 926.63 m resolution

# %%
granule.date_UTC
# Out:
# datetime.datetime(2025, 1, 17, 0, 0)

# %%
granule.variable("ST_K")
# Out:
# [2025-09-28 14:44:11 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP21A1D.002/2025-01-17/VNP21A1D.A2025017.h08v05.002.2025022014218.h5
# [2025-09-28 14:44:11 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_Daily_1km_LST21/Data Fields/LST_1KM at 926.63 m resolution
# [2025-09-28 14:44:11 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP21A1D.002/2025-01-17/VNP21A1D.A2025017.h08v05.002.2025022014218.h5
# [2025-09-28 14:44:11 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_Daily_1km_LST21/Data Fields/LST_1KM at 926.63 m resolution
